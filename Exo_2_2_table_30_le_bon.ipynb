# %%
#importation de whyqd et appelle de la methode schema
import whyqd as _w
schema = _w.Schema()

# %%
#ajout des details a mon schema
details = {
    "name":"HDR_Table_30_Schema",
    "title":"Gender inequality in education_HDR 2007-2008 Table 30",
    "description":" schema for exercice number one"
    
}
schema = _w.Schema()

schema.set_details(**details)

# %%
fields=[
        {
            "name":"Country Name",
            "title":"Country Name",
            "type":"string",
            "description":"Official country names",
            "constraints": {
                "required":True
            }
        },    
        {
            "name":"HDI Category",
            "title":"HDI Category",
            "type":"string",
            "description":"Human Development Index Category derived from the HDI Rank",
            "constraints":{
                "required": True
             }
           
        },
        {
            "name":"Indicator Name",
            "title":"Indicator Name",
            "type":"string",
            "description":"Indicator described in the data series"
        },
        {
            "name":"Values",
            "title":"Values",
            "type":"number",
            "description":"Value for the Year and Indicator Name"

        }
    ]

# %%
#ajout de fields dans mon schema
for field in fields:
    schema.set_field(**field)

# %%
directory = r"C:/Users/La licorne/Desktop/data-wrangling-course/" #je fais appel à mon repertoire courant
filename = "Lin30" # je nomme mon fichier
# le fichier existe déjà alors je spécifie "overwrite=True" pour ne pas avoir d'erreur
schema.save(directory, filename=filename, overwrite=True)
# Out:
# True

# %%
### Les importations et paramètres suivants vous permettent d'obtenir un large éventail de résultats pour vos tableaux
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))

import numpy as np
import whyqd as _w

SCHEMA_SOURCE = "lin30.json" #"lin30.json" est le nom de mon schema créé ci haut
DIRECTORY = directory
INPUT_DATA = [
    "HDR 2007-2008 Table 30.xlsx"  #"HDR 2007-2008 Table 30.xlsx" c'est le nom de mon fichier inital de la leçon 1 1
]
method = _w.Method(SCHEMA_SOURCE, directory=DIRECTORY, input_data=INPUT_DATA)
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
print(method.print_input_data())
# Out:
# Data id: 879b7019-215b-493f-819d-cb2d24290e89
# Original source: HDR 2007-2008 Table 30.xlsx
#
# ====  ============  ============  ============  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#   ..    Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9    Unnamed: 10    Unnamed: 11    Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15    Unnamed: 16    Unnamed: 17    Unnamed: 18    Unnamed: 19    Unnamed: 20    Unnamed: 21    Unnamed: 22    Unnamed: 23    Unnamed: 24    Unnamed: 25    Unnamed: 26    Unnamed: 27    Unnamed: 28    Unnamed: 29    Unnamed: 30
# ====  ============  ============  ============  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============
#    0           nan           nan           nan           nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    1           nan           nan           nan           nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
#    2           nan           nan           nan           nan           nan           nan           nan           nan           nan           nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan            nan
# ====  ============  ============  ============  ============  ============  ============  ============  ============  ============  ============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============  =============

# %%
method.status
# Out:
# 'Ready to Merge'

# %%
# Utilisez _id, ou une autre variable, puisque `id` est un terme protégé par Python
_id = method.input_data[0]["id"]
df = method.input_dataframe(_id)

# %%
df.head(12)
# Out:
#                              Unnamed: 0 Unnamed: 1  \
# 3                                   NaN        NaN
# 4   30  Gender inequality in education         NaN
# 6                                   NaN        NaN
# 7                                   NaN        NaN
# 8                                   NaN        NaN
# 11                             HDI rank        NaN
# 13               HIGH HUMAN DEVELOPMENT        NaN
# 14                                    1    Iceland
# 15                                    2     Norway
# 16                                    3  Australia
# 17                                    4     Canada
# 18                                    5    Ireland
#
#                                         Unnamed: 2  \
# 3   … and achieving equality for all women and men
# 4                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 11                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
#
#                                            Unnamed: 3 Unnamed: 4  \
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7   Adult literacya                               ...        NaN
# 8       Female rate\n(% aged 15 and older)\n1995-2005        NaN
# 11                                                NaN        NaN
# 13                                                NaN        NaN
# 14                                                 ..        NaN
# 15                                                 ..        NaN
# 16                                                 ..        NaN
# 17                                                 ..        NaN
# 18                                                 ..        NaN
#
#                                       Unnamed: 5 Unnamed: 6  \
# 3                                            NaN        NaN
# 4                                            NaN        NaN
# 6                                            NaN        NaN
# 7                                            NaN        NaN
# 8   Ratio of female rate to male rate\n1995-2005        NaN
# 11                                           NaN        NaN
# 13                                           NaN        NaN
# 14                                            ..        NaN
# 15                                            ..        NaN
# 16                                            ..        NaN
# 17                                            ..        NaN
# 18                                            ..        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7   Youth literacya                                          NaN
# 8         Female rate\n(% aged      15-24)\n1995-2005        NaN
# 11                                                NaN        NaN
# 13                                                NaN        NaN
# 14                                                 ..        NaN
# 15                                                 ..        NaN
# 16                                                 ..        NaN
# 17                                                 ..        NaN
# 18                                                 ..        NaN
#
#                                       Unnamed: 9  ...  \
# 3                                            NaN  ...
# 4                                            NaN  ...
# 6                                            MDG  ...
# 7                                            NaN  ...
# 8   Ratio of female rate to male rate\n1995-2005  ...
# 11                                           NaN  ...
# 13                                           NaN  ...
# 14                                            ..  ...
# 15                                            ..  ...
# 16                                            ..  ...
# 17                                            ..  ...
# 18                                            ..  ...
#
#                                 Unnamed: 17 Unnamed: 18  \
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# 6                                       MDG         NaN
# 7                                       NaN         NaN
# 8   Ratio of female rate to male rate\n2005         NaN
# 11                                      NaN         NaN
# 13                                      NaN         NaN
# 14                                     0.97           e
# 15                                     1.00         NaN
# 16                                     0.99         NaN
# 17                                     1.00         e,f
# 18                                     0.99         NaN
#
#                      Unnamed: 19 Unnamed: 20  \
# 3                            NaN         NaN
# 4                            NaN         NaN
# 6                            NaN         NaN
# 7   Gross secondary enrolmentb,d         NaN
# 8        Female ratio\n(%)\n2005         NaN
# 11                           NaN         NaN
# 13                           NaN         NaN
# 14                           109           e
# 15                           114         NaN
# 16                           144         NaN
# 17                           116         e,f
# 18                           118         NaN
#
#                                 Unnamed: 21 Unnamed: 22  \
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# 6                                       MDG         NaN
# 7                                       NaN         NaN
# 8   Ratio of female rate to male rate\n2005         NaN
# 11                                      NaN         NaN
# 13                                      NaN         NaN
# 14                                     1.03           e
# 15                                     1.01         NaN
# 16                                     0.95         NaN
# 17                                     0.98         e,f
# 18                                     1.09         NaN
#
#                     Unnamed: 23 Unnamed: 24  \
# 3                           NaN         NaN
# 4                           NaN         NaN
# 6                           NaN         NaN
# 7   Gross tertiary enrolmentb,d         NaN
# 8       Female ratio\n(%)\n2005         NaN
# 11                          NaN         NaN
# 13                          NaN         NaN
# 14                           93           e
# 15                           97         NaN
# 16                           80         NaN
# 17                           72         e,f
# 18                           67         NaN
#
#                                 Unnamed: 25 Unnamed: 26
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# 6                                       MDG         NaN
# 7                                       NaN         NaN
# 8   Ratio of female rate to male rate\n2005         NaN
# 11                                      NaN         NaN
# 13                                      NaN         NaN
# 14                                     1.85           e
# 15                                     1.54         NaN
# 16                                     1.25         NaN
# 17                                     1.36         e,f
# 18                                     1.27         NaN
#
# [12 rows x 27 columns]

# %%
#supresion des 11 premières lignes a adapter à ton fichier
method.add_input_data_morph(_id, ["REBASE", 11])

# %%
df.tail(20)
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 194                               Developing countries        NaN        NaN
# 195                          Least developed countries        NaN        NaN
# 196                                        Arab States        NaN        NaN
# 197                          East Asia and the Pacific        NaN        NaN
# 198                    Latin America and the Caribbean        NaN        NaN
# 199                                         South Asia        NaN        NaN
# 200                                 Sub-Saharan Africa        NaN        NaN
# 201             Central and Eastern Europe and the CIS        NaN        NaN
# 202                                               OECD        NaN        NaN
# 203                                   High-income OECD        NaN        NaN
# 205                             High human development        NaN        NaN
# 206                           Medium human development        NaN        NaN
# 207                              Low human development        NaN        NaN
# 209                                        High income        NaN        NaN
# 210                                      Middle income        NaN        NaN
# 211                                         Low income        NaN        NaN
# 213                                              World        NaN        NaN
# 220                                              NOTES        NaN        NaN
# 222  a. Data refer to national literacy estimates f...        NaN        NaN
# 224  SOURCES\nColumns 1–4: UNESCO Institute for Sta...        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 194       69.9        NaN       0.91        NaN       81.4        NaN
# 195       44.3        NaN       0.80        NaN       58.0        NaN
# 196       59.4        NaN       0.88        NaN       79.5        NaN
# 197       86.7        NaN       0.99        NaN       97.5        NaN
# 198       89.7        NaN       1.01        NaN       97.0        NaN
# 199       47.4        NaN       0.81        NaN       66.6        NaN
# 200       51.2        NaN       0.84        NaN       65.1        NaN
# 201       98.7        NaN       1.00        NaN       99.6        NaN
# 202         ..        NaN         ..        NaN         ..        NaN
# 203         ..        NaN         ..        NaN         ..        NaN
# 205       93.6        NaN       1.01        NaN       98.4        NaN
# 206       71.2        NaN       0.92        NaN       83.2        NaN
# 207       43.8        NaN       0.80        NaN       58.9        NaN
# 209         ..        NaN         ..        NaN         ..        NaN
# 210       86.5        NaN       0.99        NaN       96.2        NaN
# 211       48.8        NaN       0.82        NaN       65.8        NaN
# 213       72.7        NaN       0.92        NaN       82.5        NaN
# 220        NaN        NaN        NaN        NaN        NaN        NaN
# 222        NaN        NaN        NaN        NaN        NaN        NaN
# 224        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 9  ... Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 194       0.91  ...        0.94           i          58           i
# 195       0.80  ...        0.89           i          28           i
# 196       0.88  ...        0.90           i          65           i
# 197       0.99  ...        0.98           i          72           i
# 198       1.01  ...        0.96           i          91           i
# 199       0.81  ...        0.93           i          48           i
# 200       0.84  ...        0.89           i          28           i
# 201       1.00  ...        0.99           i          90           i
# 202         ..  ...        0.99           i          98           i
# 203         ..  ...        0.99           i         103           i
# 205       1.01  ...          ..         NaN          ..         NaN
# 206       0.92  ...          ..         NaN          ..         NaN
# 207       0.80  ...          ..         NaN          ..         NaN
# 209         ..  ...        0.99           i         102           i
# 210       0.99  ...        0.97           i          78           i
# 211       0.82  ...        0.91           i          41           i
# 213       0.92  ...        0.95           i          64           i
# 220        NaN  ...         NaN         NaN         NaN         NaN
# 222        NaN  ...         NaN         NaN         NaN         NaN
# 224        NaN  ...         NaN         NaN         NaN         NaN
#
#     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 194        0.93           i          16           i        0.91           i
# 195        0.81           i           3           i        0.63           i
# 196        0.92           i          21           i        1.01           i
# 197        1.00           i          21           i        0.93           i
# 198        1.08           i          32           i        1.17           i
# 199        0.83           i           9           i        0.74           i
# 200        0.79           i           4           i        0.62           i
# 201        0.98           i          63           i        1.30           i
# 202        1.00           i          65           i        1.17           i
# 203        1.00           i          76           i        1.20           i
# 205          ..         NaN          ..         NaN          ..         NaN
# 206          ..         NaN          ..         NaN          ..         NaN
# 207          ..         NaN          ..         NaN          ..         NaN
# 209        1.00           i          73           i        1.21           i
# 210        1.01           i          28           i        1.09           i
# 211        0.82           i           7           i        0.68           i
# 213        0.94           i          25           i        1.05           i
# 220         NaN         NaN         NaN         NaN         NaN         NaN
# 222         NaN         NaN         NaN         NaN         NaN         NaN
# 224         NaN         NaN         NaN         NaN         NaN         NaN
#
# [20 rows x 27 columns]

# %%
# suppression des lignes a partir de la ligne 193 
rows = [int(i) for i in np.arange(193, df.index[-1]+1)]
method.add_input_data_morph(_id, ["DELETE", rows])

# %%
df = method.input_dataframe(_id) #Actualise
df.tail(10)
# Out:
#     HDI rank                                 NaN  NaN   NaN  NaN   NaN  NaN  \
# 183      168  Congo (Democratic Republic of the)  NaN  54.1  NaN  0.67  NaN
# 184      169                            Ethiopia  NaN  22.8  NaN  0.46  NaN
# 185      170                                Chad  NaN  12.8  NaN  0.31  NaN
# 186      171            Central African Republic  NaN  33.5  NaN  0.52  NaN
# 187      172                          Mozambique  NaN  25.0  NaN  0.46  NaN
# 188      173                                Mali  NaN  15.9  NaN  0.49  NaN
# 189      174                               Niger  NaN  15.1  NaN  0.35  NaN
# 190      175                       Guinea-Bissau  NaN    ..  NaN    ..  NaN
# 191      176                        Burkina Faso  NaN  16.6  NaN  0.53  NaN
# 192      177                        Sierra Leone  NaN  24.2  NaN  0.52  NaN
#
#       NaN  NaN   NaN  ...   NaN  NaN NaN  NaN   NaN  NaN  NaN  NaN   NaN  NaN
# 183  63.1  NaN  0.81  ...  0.78  e,f  16  e,f  0.58  e,f   ..  NaN    ..  NaN
# 184  38.5  NaN  0.62  ...  0.86  NaN  24  NaN  0.65  NaN    1  NaN  0.32  NaN
# 185  23.2  NaN  0.42  ...  0.67  NaN   8    e  0.33    e  (.)    e  0.14    e
# 186  46.9  NaN  0.67  ...  0.66    e  ..  NaN    ..  NaN   ..  NaN    ..  NaN
# 187  36.6  NaN  0.61  ...  0.85  NaN  11  NaN  0.69  NaN    1  NaN  0.49  NaN
# 188  16.9  NaN  0.52  ...  0.80  NaN  18    e  0.62    e    2    e  0.47    e
# 189  23.2  NaN  0.44  ...  0.73  NaN   7  NaN  0.68  NaN    1  NaN  0.45  NaN
# 190    ..  NaN    ..  ...  0.67  e,f  13  e,f  0.54  e,f  (.)  e,f  0.18  e,f
# 191  26.5  NaN  0.66  ...  0.80  NaN  12  NaN  0.70  NaN    1  NaN  0.45  NaN
# 192  37.4  NaN  0.63  ...  0.71    f  22  e,f  0.71  e,f    1  e,f  0.40  e,f
#
# [10 rows x 27 columns]

# %%
columns = [
    "rank",
    "Country",
    "vide",
    "Ad_lit_Fem_rate",
    "Reference1",
    "Ad_lit_rat_femrate_malrate",
    "Reference2",
    "Yout_lit_Fem_rate",  
    "Reference3",
    "Yout_lit_rat_femrate_malrate",
    "Reference4",
    "Net_prim_enr_fem_rate",
    "Reference5",
    "Net_prim_enr_rat_femrate_malrate",
    "Reference6",
    "Gross_prim_enr_fem_rat",   
    "Reference7",
    "Gross_prim_enr_rat_femrate_malrate",   
    "Reference8",
    "Gross_sec_enr_femrat",
    "Reference9",
    "Gross_sec_enr_rat_femrate_malrate",
    "Reference10",
    "Gross_tert_enr_female_rat",
    "Reference11",
    "Gross_tert_enr_rat_femrate_malrate",
    "Reference12"
]

# %%
#renommer les colonnes 
method.add_input_data_morph(_id, ["RENAME", columns])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#                       rank    Country vide Ad_lit_Fem_rate Reference1  \
# 13  HIGH HUMAN DEVELOPMENT        NaN  NaN             NaN        NaN
# 14                       1    Iceland  NaN              ..        NaN
# 15                       2     Norway  NaN              ..        NaN
# 16                       3  Australia  NaN              ..        NaN
# 17                       4     Canada  NaN              ..        NaN
#
#    Ad_lit_rat_femrate_malrate Reference2 Yout_lit_Fem_rate Reference3  \
# 13                        NaN        NaN               NaN        NaN
# 14                         ..        NaN                ..        NaN
# 15                         ..        NaN                ..        NaN
# 16                         ..        NaN                ..        NaN
# 17                         ..        NaN                ..        NaN
#
#    Yout_lit_rat_femrate_malrate  ... Gross_prim_enr_rat_femrate_malrate  \
# 13                          NaN  ...                                NaN
# 14                           ..  ...                               0.97
# 15                           ..  ...                               1.00
# 16                           ..  ...                               0.99
# 17                           ..  ...                               1.00
#
#    Reference8 Gross_sec_enr_femrat Reference9  \
# 13        NaN                  NaN        NaN
# 14          e                  109          e
# 15        NaN                  114        NaN
# 16        NaN                  144        NaN
# 17        e,f                  116        e,f
#
#    Gross_sec_enr_rat_femrate_malrate Reference10 Gross_tert_enr_female_rat  \
# 13                               NaN         NaN                       NaN
# 14                              1.03           e                        93
# 15                              1.01         NaN                        97
# 16                              0.95         NaN                        80
# 17                              0.98         e,f                        72
#
#    Reference11 Gross_tert_enr_rat_femrate_malrate Reference12
# 13         NaN                                NaN         NaN
# 14           e                               1.85           e
# 15         NaN                               1.54         NaN
# 16         NaN                               1.25         NaN
# 17         e,f                               1.36         e,f
#
# [5 rows x 27 columns]

# %%
method.add_input_data_morph(_id, ["DEBLANK"])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#                       rank    Country Ad_lit_Fem_rate Reference1  \
# 13  HIGH HUMAN DEVELOPMENT        NaN             NaN        NaN
# 14                       1    Iceland              ..        NaN
# 15                       2     Norway              ..        NaN
# 16                       3  Australia              ..        NaN
# 17                       4     Canada              ..        NaN
#
#    Ad_lit_rat_femrate_malrate Reference2 Yout_lit_Fem_rate Reference3  \
# 13                        NaN        NaN               NaN        NaN
# 14                         ..        NaN                ..        NaN
# 15                         ..        NaN                ..        NaN
# 16                         ..        NaN                ..        NaN
# 17                         ..        NaN                ..        NaN
#
#    Yout_lit_rat_femrate_malrate Reference4  ...  \
# 13                          NaN        NaN  ...
# 14                           ..        NaN  ...
# 15                           ..        NaN  ...
# 16                           ..        NaN  ...
# 17                           ..        NaN  ...
#
#    Gross_prim_enr_rat_femrate_malrate Reference8 Gross_sec_enr_femrat  \
# 13                                NaN        NaN                  NaN
# 14                               0.97          e                  109
# 15                               1.00        NaN                  114
# 16                               0.99        NaN                  144
# 17                               1.00        e,f                  116
#
#    Reference9 Gross_sec_enr_rat_femrate_malrate Reference10  \
# 13        NaN                               NaN         NaN
# 14          e                              1.03           e
# 15        NaN                              1.01         NaN
# 16        NaN                              0.95         NaN
# 17        e,f                              0.98         e,f
#
#    Gross_tert_enr_female_rat Reference11 Gross_tert_enr_rat_femrate_malrate  \
# 13                       NaN         NaN                                NaN
# 14                        93           e                               1.85
# 15                        97         NaN                               1.54
# 16                        80         NaN                               1.25
# 17                        72         e,f                               1.36
#
#    Reference12
# 13         NaN
# 14           e
# 15         NaN
# 16         NaN
# 17         e,f
#
# [5 rows x 26 columns]

# %%
# Obtenir les indices des lignes de données catégorielles
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
rows = df[df["rank"].isin(hdi_categories)].index

# %%
rows
# Out:
# Int64Index([13, 84, 170], dtype='int64')

# %%
# categoriser en fonction de HDI categorie
method.add_input_data_morph(_id, ["CATEGORISE", list(rows), "HDI category"])

# %%
df = method.input_dataframe(_id)
df.head(10)
# Out:
#    rank      Country Ad_lit_Fem_rate Reference1 Ad_lit_rat_femrate_malrate  \
# 14    1      Iceland              ..        NaN                         ..
# 15    2       Norway              ..        NaN                         ..
# 16    3    Australia              ..        NaN                         ..
# 17    4       Canada              ..        NaN                         ..
# 18    5      Ireland              ..        NaN                         ..
# 19    6       Sweden              ..        NaN                         ..
# 20    7  Switzerland              ..        NaN                         ..
# 21    8        Japan              ..        NaN                         ..
# 22    9  Netherlands              ..        NaN                         ..
# 23   10       France              ..        NaN                         ..
#
#    Reference2 Yout_lit_Fem_rate Reference3 Yout_lit_rat_femrate_malrate  \
# 14        NaN                ..        NaN                           ..
# 15        NaN                ..        NaN                           ..
# 16        NaN                ..        NaN                           ..
# 17        NaN                ..        NaN                           ..
# 18        NaN                ..        NaN                           ..
# 19        NaN                ..        NaN                           ..
# 20        NaN                ..        NaN                           ..
# 21        NaN                ..        NaN                           ..
# 22        NaN                ..        NaN                           ..
# 23        NaN                ..        NaN                           ..
#
#    Reference4  ... Reference8 Gross_sec_enr_femrat Reference9  \
# 14        NaN  ...          e                  109          e
# 15        NaN  ...        NaN                  114        NaN
# 16        NaN  ...        NaN                  144        NaN
# 17        NaN  ...        e,f                  116        e,f
# 18        NaN  ...        NaN                  118        NaN
# 19        NaN  ...        NaN                  103        NaN
# 20        NaN  ...        NaN                   91        NaN
# 21        NaN  ...        NaN                  102        NaN
# 22        NaN  ...        NaN                  117        NaN
# 23        NaN  ...        NaN                  116        NaN
#
#    Gross_sec_enr_rat_femrate_malrate Reference10 Gross_tert_enr_female_rat  \
# 14                              1.03           e                        93
# 15                              1.01         NaN                        97
# 16                              0.95         NaN                        80
# 17                              0.98         e,f                        72
# 18                              1.09         NaN                        67
# 19                              1.00         NaN                       100
# 20                              0.93         NaN                        43
# 21                              1.00         NaN                        52
# 22                              0.98         NaN                        63
# 23                              1.00         NaN                        64
#
#    Reference11 Gross_tert_enr_rat_femrate_malrate Reference12  \
# 14           e                               1.85           e
# 15         NaN                               1.54         NaN
# 16         NaN                               1.25         NaN
# 17         e,f                               1.36         e,f
# 18         NaN                               1.27         NaN
# 19         NaN                               1.55         NaN
# 20         NaN                               0.84         NaN
# 21         NaN                               0.89         NaN
# 22         NaN                               1.08         NaN
# 23         NaN                               1.29         NaN
#
#               HDI category
# 14  HIGH HUMAN DEVELOPMENT
# 15  HIGH HUMAN DEVELOPMENT
# 16  HIGH HUMAN DEVELOPMENT
# 17  HIGH HUMAN DEVELOPMENT
# 18  HIGH HUMAN DEVELOPMENT
# 19  HIGH HUMAN DEVELOPMENT
# 20  HIGH HUMAN DEVELOPMENT
# 21  HIGH HUMAN DEVELOPMENT
# 22  HIGH HUMAN DEVELOPMENT
# 23  HIGH HUMAN DEVELOPMENT
#
# [10 rows x 27 columns]

# %%
columns = [
    "rank",
    "Ad_lit_Fem_rate",
    "Ad_lit_rat_femrate_malrate",
    "Yout_lit_Fem_rate",
    "Yout_lit_rat_femrate_malrate",
    "Net_prim_enr_fem_rate",
    "Net_prim_enr_rat_femrate_malrate",
    "Gross_prim_enr_fem_rat", 
    "Gross_prim_enr_rat_femrate_malrate",   
    "Gross_sec_enr_femrat",
    "Gross_sec_enr_rat_femrate_malrate",
    "Gross_tert_enr_female_rat",
    "Gross_tert_enr_rat_femrate_malrate",
]
method.add_input_data_morph(_id, ["MELT", columns, ["Indicator Name", "Indicator Value"]])

# %%
columns = [
    "Reference1",
    "Reference2",  
    "Reference3",
    "Reference4",
    "Reference5",
    "Reference6",  
    "Reference7",   
    "Reference8",
    "Reference9",
    "Reference10",
    "Reference11",
    "Reference12"
]
method.add_input_data_morph(_id, ["MELT", columns, ["Reference Name", "Reference"]])

# %%
df = method.input_dataframe(_id)
df.head()
# Out:
#              HDI category Indicator Name Indicator Value    Country  \
# 0  HIGH HUMAN DEVELOPMENT           rank               1    Iceland
# 1  HIGH HUMAN DEVELOPMENT           rank               2     Norway
# 2  HIGH HUMAN DEVELOPMENT           rank               3  Australia
# 3  HIGH HUMAN DEVELOPMENT           rank               4     Canada
# 4  HIGH HUMAN DEVELOPMENT           rank               5    Ireland
#
#   Reference Name Reference
# 0     Reference1       NaN
# 1     Reference1       NaN
# 2     Reference1       NaN
# 3     Reference1       NaN
# 4     Reference1       NaN

# %%
# %time method.merge(overwrite_working=True) #génère un fichier avec en sortir le traitement appliqué
# Out:
# Wall time: 51.4 s

# %%
structure = {
    "country_name": ["RENAME", "Country"],
    "hdi_category": ["RENAME", "HDI category"],
    "indicator_name": ["RENAME", "Indicator Name"],
    "values": ["RENAME", "Indicator Value"],
}
# Notez le "**" au début du nom du paramètre
# Ceci "dépaquette"  le dictionnaire de sorte que tous les termes soient visibles pour la fonction
method.set_structure(**structure)

# %%
method.transform(overwrite_output=True)
FILENAME = "hdi_report_exercise"
method.save(directory, filename=FILENAME, overwrite=True)

# %%
method.input_data_morphs(_id)
# Out:
# [{'065e2da6-9703-4a54-9831-7db4ed245f20': ['DEBLANK']},
#  {'5c1e7bb3-2f8c-47dc-8058-51f70e31a9a3': ['DEDUPE']},
#  {'a69129a0-f613-4b79-a16f-347efcbc4106': ['REBASE', [11]]},
#  {'c13e2dc2-bd31-48c7-8e89-7d54401e6130': ['DELETE',
#    [193,
#     194,
#     195,
#     196,
#     197,
#     198,
#     199,
#     200,
#     201,
#     202,
#     203,
#     204,
#     205,
#     206,
#     207,
#     208,
#     209,
#     210,
#     211,
#     212,
#     213,
#     214,
#     215,
#     216,
#     217,
#     218,
#     219,
#     220,
#     221,
#     222,
#     223,
#     224]]},
#  {'74c318da-5c6d-4975-8016-79636161f134': ['RENAME',
#    ['rank',
#     'Country',
#     'vide',
#     'Ad_lit_Fem_rate',
#     'Reference1',
#     'Ad_lit_rat_femrate_malrate',
#     'Reference2',
#     'Yout_lit_Fem_rate',
#     'Reference3',
#     'Yout_lit_rat_femrate_malrate',
#     'Reference4',
#     'Net_prim_enr_fem_rate',
#     'Reference5',
#     'Net_prim_enr_rat_femrate_malrate',
#     'Reference6',
#     'Gross_prim_enr_fem_rat',
#     'Reference7',
#     'Gross_prim_enr_rat_femrate_malrate',
#     'Reference8',
#     'Gross_sec_enr_femrat',
#     'Reference9',
#     'Gross_sec_enr_rat_femrate_malrate',
#     'Reference10',
#     'Gross_tert_enr_female_rat',
#     'Reference11',
#     'Gross_tert_enr_rat_femrate_malrate',
#     'Reference12']]},
#  {'83120e5a-cb9f-4341-a9f4-b72feccc18d4': ['DEBLANK']},
#  {'16043c7b-2bbd-4c47-b356-53f6a92b266b': ['CATEGORISE',
#    [13, 84, 170],
#    ['HDI category']]},
#  {'0e304701-9cb6-49be-829a-b447b934c1b6': ['MELT',
#    [['HDI category',
#      'Reference5',
#      'Reference6',
#      'Reference12',
#      'Reference9',
#      'Reference10',
#      'Reference4',
#      'Reference11',
#      'Reference1',
#      'Reference8',
#      'Reference2',
#      'Country',
#      'Reference3',
#      'Reference7'],
#     ['rank',
#      'Ad_lit_Fem_rate',
#      'Ad_lit_rat_femrate_malrate',
#      'Yout_lit_Fem_rate',
#      'Yout_lit_rat_femrate_malrate',
#      'Net_prim_enr_fem_rate',
#      'Net_prim_enr_rat_femrate_malrate',
#      'Gross_prim_enr_fem_rat',
#      'Gross_prim_enr_rat_femrate_malrate',
#      'Gross_sec_enr_femrat',
#      'Gross_sec_enr_rat_femrate_malrate',
#      'Gross_tert_enr_female_rat',
#      'Gross_tert_enr_rat_femrate_malrate']],
#    ['Indicator Name', 'Indicator Value']]},
#  {'df26bd79-20ed-4656-97ea-344c7e99f2c1': ['MELT',
#    [['HDI category', 'Indicator Name', 'Indicator Value', 'Country'],
#     ['Reference1',
#      'Reference2',
#      'Reference3',
#      'Reference4',
#      'Reference5',
#      'Reference6',
#      'Reference7',
#      'Reference8',
#      'Reference9',
#      'Reference10',
#      'Reference11',
#      'Reference12']],
#    ['Reference Name', 'Reference']]}]

# %%
# %time method.validates
# Out:
# Wall time: 1min 2s
# True

# %%
import pandas as pd
import numpy as np

source = "output_9fb333fa-c506-4d76-955e-3d95b6b62376.csv"

df = pd.read_csv(source)
df.head()
# Out:
#   country_name            hdi_category indicator_name values
# 0      Iceland  HIGH HUMAN DEVELOPMENT           rank      1
# 1       Norway  HIGH HUMAN DEVELOPMENT           rank      2
# 2    Australia  HIGH HUMAN DEVELOPMENT           rank      3
# 3       Canada  HIGH HUMAN DEVELOPMENT           rank      4
# 4      Ireland  HIGH HUMAN DEVELOPMENT           rank      5

# %%
from pandas_schema import Column, Schema
from pandas_schema.validation import LeadingWhitespaceValidation, TrailingWhitespaceValidation, IsDtypeValidation, InListValidation

# Nous ne testerons que ces colonnes
columns = ["country_name", "hdi_category", "values"]
# Et ces catégories
hdi_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]

# %%
schema = Schema([
    Column("country_name", [LeadingWhitespaceValidation(), TrailingWhitespaceValidation()]),
    Column("hdi_category", [InListValidation(hdi_categories)]),
    Column("values", [IsDtypeValidation(np.dtype(float)), IsDtypeValidation(np.dtype(int))])
])

# %%
errors = schema.validate(df[columns])

print(F"Nombre d'erreurs :  {len(errors)}")
# Juste les 10 premiers
for error in errors[:10]:
    print(error)
# Out:
# Nombre d'erreurs :  171
# The column values has a dtype of object which is not a subclass of the required type float64
# The column values has a dtype of object which is not a subclass of the required type int32
# {row: 164, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 165, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 166, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 167, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 168, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 169, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 170, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)
# {row: 171, column: "hdi_category"}: "nan" is not in the list of legal options (HIGH HUMAN DEVELOPMENT, MEDIUM HUMAN DEVELOPMENT, LOW HUMAN DEVELOPMENT)

# %%
for l in method.citation.split(","):
    print(l)
# Out:
# 2020-05-26
#  Gender inequality in education_HDR 2007-2008 Table 30
#  1612a339313d79412ff2845aae3b7140039edd682f42fd4cfb2c007a8fb857e85e823d569fe3ba8f098955b4ee243b749e31bf0c49e7f84ae856fa43e4997bd1
#  [input sources: HDR 2007-2008 Table 30.xlsx
#  2990cac3190e2e6b57bd10df83efbd0e5124bdbc8d5e57d031cb0f7c8ff9cf4a54b1b48e6b4a34c053e928fe61923374d507ec0ccbcc1a2d2f36f46cdd2207bb]
